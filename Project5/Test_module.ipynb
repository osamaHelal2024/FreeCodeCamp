# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("Epa_Level_Sea.csv")

# %%
data.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
data['CSIRO Adjusted Sea Level'].value_counts(dropna= False)
# Out:
# 3.098425    3
# 1.854331    2
# 1.791339    2
# 1.905512    2
# 2.047244    2
#            ..
# 2.031496    1
# 2.106299    1
# 1.795276    1
# 1.547244    1
# NaN         1
# Name: CSIRO Adjusted Sea Level, Length: 129, dtype: int64

# %%
data['CSIRO Adjusted Sea Level'].fillna(data['CSIRO Adjusted Sea Level'].mean() , inplace = True)

# %%
data['CSIRO Adjusted Sea Level'].value_counts(dropna= False)
# Out:
# 3.098425    3
# 1.854331    2
# 1.791339    2
# 1.905512    2
# 2.047244    2
#            ..
# 2.031496    1
# 2.106299    1
# 1.795276    1
# 1.547244    1
# 3.650341    1
# Name: CSIRO Adjusted Sea Level, Length: 129, dtype: int64

# %%
data['Lower Error Bound'].unique()
# Out:
# array([-0.9527559 , -0.73228346, -1.34645669, -1.12992126, -0.28346457,
#        -0.33070866, -0.38188976, -0.6023622 , -0.51968504, -0.45669291,
#        -0.37401575, -0.44094488, -0.31496063, -0.11417323, -0.54724409,
#        -0.08267716, -0.36614173, -0.14566929,  0.26771653,  0.57480315,
#         0.40551181,  0.41732283,  0.61023622,  0.93700787,  0.53543307,
#         0.37795276,  0.67322835,  0.52755905,  0.7007874 ,  0.69685039,
#         1.03937008,  0.91732283,  0.99212598,  1.2519685 ,  1.57086614,
#         1.51968504,  1.3503937 ,  1.29133858,  1.35433071,  1.39370079,
#         1.47244094,  1.43307086,  1.48818897,  1.19685039,  1.25590551,
#         1.50787401,  1.49606299,  1.36614173,  1.42913386,  1.59055118,
#         1.56692913,  1.8031496 ,  1.97637795,  1.75984252,  1.98031496,
#         1.83070866,  2.05511811,  2.15748031,  2.34645669,  2.18110236,
#         2.67322834,  2.42519685,  2.53543307,  2.83464567,  2.99606299,
#         3.19685039,  3.18110236,  3.28740157,  3.66535433,  3.56692913,
#         3.74803149,  3.64173228,  3.68503937,  3.48818897,  4.01968504,
#         4.08661417,  4.1023622 ,  4.24409448,  4.48818897,  4.28346456,
#         4.22047244,  3.90551181,  4.34645669,  4.13779527,  4.19685039,
#         4.47637795,  4.4015748 ,  4.61023622,  4.96850393,  4.73622047,
#         5.2047244 ,  5.14566929,  5.1023622 ,  5.04330708,  5.29133858,
#         5.09842519,  5.34251968,  5.83070865,  5.61023621,  5.93307086,
#         5.9055118 ,  5.49999999,  5.52362204,  5.5511811 ,  5.73228346,
#         5.97244094,  6.07480314,  6.09448818,  6.02755905,  6.23622047,
#         6.3543307 ,  6.52362204,  6.8031496 ,  6.39370078,  6.73622047,
#         6.79133858,  7.01968503,  7.11023621,  7.48425196,  7.46456692,
#         7.47244094,  7.64566928,  7.71259842,  8.07874015,  8.31102361,
#         8.61811023,  8.66141731,  8.99212598,  8.62204724,         nan])

# %%
data['Lower Error Bound'].value_counts(dropna= False)
# Out:
#  2.673228    3
#  5.905512    2
#  4.220472    2
#  0.610236    2
# -0.952756    1
#             ..
#  1.354331    1
#  1.291339    1
#  1.350394    1
#  1.519685    1
#  NaN         1
# Name: Lower Error Bound, Length: 130, dtype: int64

# %%
data['Lower Error Bound'].fillna(data['Lower Error Bound'].mean() , inplace= True)

# %%
data['Lower Error Bound']
# Out:
# 0     -0.952756
# 1     -0.732283
# 2     -1.346457
# 3     -1.129921
# 4     -0.283465
#          ...
# 130    8.618110
# 131    8.661417
# 132    8.992126
# 133    8.622047
# 134    3.204666
# Name: Lower Error Bound, Length: 135, dtype: float64

# %%
data['NOAA Adjusted Sea Level'].unique()
# Out:
# array([       nan, 6.29749305, 6.31093355, 6.45256866, 6.62763131,
#        6.73392037, 6.86580607, 6.84868977, 6.92058201, 7.08746001,
#        7.31969752, 7.48835272, 7.50793284, 7.64456314, 7.69742001,
#        7.70214715, 7.90736541, 8.04635409, 8.12297257, 8.053065  ,
#        8.45705763, 8.54664823, 8.66370039])

# %%
data['NOAA Adjusted Sea Level'].value_counts(dropna= False)
# Out:
# NaN         113
# 7.507933      1
# 8.546648      1
# 8.457058      1
# 8.053065      1
# 8.122973      1
# 8.046354      1
# 7.907365      1
# 7.702147      1
# 7.697420      1
# 7.644563      1
# 7.488353      1
# 6.297493      1
# 7.319698      1
# 7.087460      1
# 6.920582      1
# 6.848690      1
# 6.865806      1
# 6.733920      1
# 6.627631      1
# 6.452569      1
# 6.310934      1
# 8.663700      1
# Name: NOAA Adjusted Sea Level, dtype: int64

# %%
data['NOAA Adjusted Sea Level'].fillna(data['NOAA Adjusted Sea Level'].median() , inplace = True)

# %%
data['NOAA Adjusted Sea Level'].unique()
# Out:
# array([7.49814278, 6.29749305, 6.31093355, 6.45256866, 6.62763131,
#        6.73392037, 6.86580607, 6.84868977, 6.92058201, 7.08746001,
#        7.31969752, 7.48835272, 7.50793284, 7.64456314, 7.69742001,
#        7.70214715, 7.90736541, 8.04635409, 8.12297257, 8.053065  ,
#        8.45705763, 8.54664823, 8.66370039])

# %%
data['Upper Error Bound'].fillna(data['Upper Error Bound'].mean() , inplace= True)

# %%
data['Upper Error Bound'].unique()
# Out:
# array([0.9527559 , 1.17322835, 0.46456693, 0.66535433, 1.46456693,
#        1.39370079, 1.25590551, 1.03543307, 1.11811024, 1.18110236,
#        1.18897638, 1.31496063, 1.48425197, 1.15354331, 1.61811024,
#        1.3031496 , 1.49212598, 1.81889764, 2.1023622 , 1.84645669,
#        1.8031496 , 1.97244094, 2.27559055, 1.86614173, 1.59055118,
#        1.83070866, 1.78346457, 1.66929134, 1.8503937 , 2.15748031,
#        2.03543307, 2.33858268, 2.64173228, 2.54330708, 2.35826771,
#        2.29133858, 2.35433071, 2.41732283, 2.50393701, 2.47244094,
#        2.51181102, 2.22834645, 2.32677165, 2.58661417, 2.33464567,
#        2.38188976, 2.53543307, 2.52755905, 2.74015748, 2.90551181,
#        2.69685039, 2.91732283, 2.75984252, 2.98425196, 3.08661417,
#        3.30708661, 3.05511811, 3.52362204, 3.26771653, 3.37795275,
#        3.66929134, 3.7519685 , 3.92913385, 3.84251968, 3.90944882,
#        4.27952755, 4.17322834, 4.33858267, 4.21653543, 4.24409448,
#        4.03937007, 4.56299212, 4.60629921, 4.61417322, 4.76377952,
#        5.00787401, 4.8031496 , 4.74015748, 4.43307086, 4.87401574,
#        4.65748031, 4.70866141, 4.74803149, 5.02755905, 4.9527559 ,
#        5.1535433 , 5.51181102, 5.27165354, 5.74015747, 5.67322834,
#        5.63779527, 5.56299212, 5.81889763, 5.62598425, 5.8543307 ,
#        6.34251968, 6.10629921, 6.44488188, 6.4015748 , 5.99606299,
#        6.01968503, 6.03937007, 6.22834645, 6.40944881, 6.49212598,
#        6.59448818, 6.62204724, 6.5551181 , 6.76377952, 6.88188976,
#        7.05118109, 7.33070865, 6.93700787, 7.28740157, 7.33464566,
#        7.5551181 , 7.6535433 , 8.03543306, 8.01574802, 8.18897637,
#        8.27952755, 8.62204724, 8.86220472, 9.18503936, 9.26771653,
#        9.66141731, 9.33858267, 4.09601598])

# %% [markdown]
# # stage 2

# %%
plt.scatter(data['Year'] , data['CSIRO Adjusted Sea Level'])
plt.title(" CSIRO Adjusted Sea Level in  Years ")
plt.xlabel("Year") 
plt.ylabel("CSIRO Adjusted Sea Level")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from scipy import stats 
from scipy import interpolate

# %%
m = stats.linregress(data['Year'] ,  data['CSIRO Adjusted Sea Level'] )

# %%
m.slope
# Out:
# 0.061653894658926005

# %%
m.intercept
# Out:
# -116.38979208904834

# %%
CSIRO_Adjusted_Sea_Level = np.array(data['CSIRO Adjusted Sea Level'])

# %%
x = data['Year']

# %%
plt.plot(data['Year'] , data['CSIRO Adjusted Sea Level'] , 'o' , label = "original data")
plt.plot(x, m.intercept + m.slope*x, 'r', label='fitted line')
plt.title(" CSIRO Adjusted Sea Level in  Years ")
plt.xlabel("Year") 
plt.ylabel("CSIRO Adjusted Sea Level")
plt.legend()

# %%
def regerssion(input) : 
     plt.plot(data['Year'],data['CSIRO Adjusted Sea Level'], 'o') 
     plt.plot(input , m.intercept + m.slope * input , 'r' , label = "Fitted line ")
     plt.title(" CSIRO Adjusted Sea Level in  Years ")
plt.xlabel("Year") 
plt.ylabel("CSIRO Adjusted Sea Level")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x = np.arange(1880 , 2061 , 1 )

# %%
x
# Out:
# array([1880, 1881, 1882, 1883, 1884, 1885, 1886, 1887, 1888, 1889, 1890,
#        1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901,
#        1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912,
#        1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923,
#        1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934,
#        1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945,
#        1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#        1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#        1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#        1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033,
#        2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044,
#        2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055,
#        2056, 2057, 2058, 2059, 2060])

# %%
regerssion(x)

# %%
val_2050 = m.intercept + m.slope * 2050

# %%
val_2050
# Out:
# 10.000691961749965
